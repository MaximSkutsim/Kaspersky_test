# %%
from collections import Counter
import requests
import pandas as pd
import time
import os

# %%
#  Инициализация фунции для сентимент-анализа упоминания  компаниии с использованием API к модели YandeXGPT
def baseline_sentiment(sentence: str, company: str,   retries: int = 5, delay: int = 1, model: str = 'lite') -> str | None:
    """
    Классифицирует тональность предложения с упоминанием компании, возвращая одно из значений: 'negative', 'neutral' или 'positive'.

    Параметры:
    - sentence (str): Предложение, в котором необходимо оценить тональность.
    - company (str): Название компании, упоминание которой оценивается.
    - retries (int, по умолчанию 5): Количество попыток при неудачном запросе.
    - delay (int, по умолчанию 1): Время задержки между повторными попытками в секундах.
    - model (str, по умолчанию 'lite'): Тип модели для использования — 'lite' для упрощённой версии или 'pro' для полной версии.

    Возвращаемое значение:
    - str: Одно из значений 'negative', 'neutral' или 'positive', если запрос выполнен успешно.
    - None: Если произошла ошибка или количество попыток исчерпано.
    """

    # URL для обращения к модели Yandex GPT
    URL = "https://llm.api.cloud.yandex.net/foundationModels/v1/completion"
    # Получаем API ключ и ID папки из переменных окружения
    api_key = os.getenv("API_KEY")
    folder_id = os.getenv("FOLDER_ID")

    # Инициализируем пустой словарь для данных запроса
    data = {}

    # Выбор модели в зависимости от переданного параметра
    if model == 'lite':
        data["modelUri"] = f"gpt://{folder_id}/yandexgpt-lite/latest"  # lite-версия модели
    elif model == 'pro':
        data["modelUri"] = f"gpt://{folder_id}/yandexgpt/latest"  # pro-версия модели
    else:
        print("Неправильная модель, доступные модели 'lite' и 'pro'")
        return None  # Завершаем выполнение функции, если модель указана неверно

    # Настройка опций генерации
    data["completionOptions"] = {"temperature": 0.3, "maxTokens": 500}  # Температура и максимальное количество токенов

    # Простой системный промт для модели с инструкцией по оценке тональности
    system_prompt = f"""Оцени тональность упоминания компании {company}, ответь одним словом negative, neutral или positive.
    Запомни: в ответе должно быть только одно слово - negative, neutral или positive, без пояснений и дополнительного текста."""

    # Формируем сообщения для передачи в модель (системный и пользовательский контекст)
    data["messages"] = [
        {"role": "system", "text": system_prompt},  # Системная инструкция
        {"role": "user", "text": sentence}  # Текст, который пользователь хочет классифицировать
    ]

    # Цикл для повторных попыток запроса в случае ошибки или превышения лимитов
    for attempt in range(retries):
        try:
            # Отправляем POST-запрос к API Yandex GPT с данными и заголовками
            response = requests.post(
                URL,
                headers={
                    "Accept": "application/json",
                    "Authorization": f"Api-Key {api_key}"  # Авторизация с использованием API ключа
                },
                json=data,  # Передаем данные запроса
            ).json()

            # Возвращаем результат — одно слово с оценкой тональности, переведенное в нижний регистр
            return response["result"]["alternatives"][0]['message']['text'].lower().rstrip(".")

        except Exception as e:
            # Проверяем, если произошла ошибка лимита запросов (HTTP 429)
            if response.get('error', {}).get('httpCode') == 429:
                print(f"Превышен лимит запросов. Попытка {attempt + 1} из {retries}. Ожидание {delay} секунд.")
                time.sleep(delay)  # Ждем перед новой попыткой
            else:
                # Любая другая ошибка выводится в консоль
                print(f"Произошла ошибка: {e}")
                return None  # Возвращаем None при ошибке

    # Если все попытки исчерпаны, выводим сообщение
    print("Превышено количество попыток.")
    return None  # Возвращаем None, если все попытки завершились неудачно

# %%
# Импорт данных из файла
data = pd.read_excel('ru_data_test.xlsx')
data.head(2)
# Out:
#                                             sentence                   object  \
# 0  Схему обнаружили аналитики департамента Digita...  Digital Risk Protection
# 1  Лидеры ВОГ не избавлялись от непрофильных акти...                      ВОГ
#
#    tonality
# 0  positive
# 1  negative

# %% [markdown]
# # Baseline

# %%
# Добавим в dataframe столбец с результатами функции baseline_sentiment()
data['sentiment-lite'] = data.apply(lambda row: baseline_sentiment(row['sentence'], row['object'],   model='lite'), axis=1)

# %%
# Оценка точность модели
accuracy =len(data[data['sentiment-lite'] == data['tonality']])/len(data)
print(f"Точность lite модели: {accuracy}")
# Out:
# Точность lite модели: 0.6306306306306306

# %%
# Позиции с ошибочными оценками
data[data['sentiment-lite'] != data['tonality']]
# Out:
#                                               sentence  \
# 0    Схему обнаружили аналитики департамента Digita...
# 4    В январе в Microsoft заявили, что киберпреступ...
# 5    Атака NGC2180 была обнаружена специалистами Со...
# 6    ИБ компания Proofpoint обнаружила, что группир...
# 10   Специалисты FortiGuard Labs выявили новый вари...
# 14   ИБ компания GuidePoint Security обнаружила, чт...
# 21   Также в марте Вкусвилл получил 80% в компании ...
# 24   Softline через свою 100% ную дочку Скай Технол...
# 25   Скай Технолоджис , на 100% дочерняя ГК Softlin...
# 26   Словацкая компания ESET обнаружила деятельност...
# 32   Экспертный центр безопасности Positive Technol...
# 34   Евгений присоединился к NGR Softlab в 2023 г.,...
# 35   Российский разработчик решений по информационн...
# 43   Эту схему, получившую название Crescendo, обна...
# 45   В сентябре 2021 г. основателя компании Group I...
# 48   Ранее, в 2021 г., специалисты Positive Technol...
# 51   В 2023 году Лаборатория Касперского обнаружила...
# 52   В 2022 году исследователи из компании Zscaler,...
# 53   Исследователи Dr Web обнаружили множество прил...
# 54   Напомним, что недавно специалисты Bitdefender ...
# 56   Игровой издатель и разработчик Astrum Entertai...
# 58   QIWI Банк стал первым лишенным лицензии банком...
# 66   На фоне недавних президентских выборов в РФ, и...
# 70   К Angara Security на позиции директора по упра...
# 71   Из технологических компаний в новом санкционно...
# 72   Также под ограничения со стороны Киева попали ...
# 74   С 20 марта в России перестанут работать облачн...
# 75   Обращаем внимание, что речь может идти о всех ...
# 76   Уточняется, что запрет вступает в силу с 20 ма...
# 83   В 2022 г. администрация GitLab объявила о ввод...
# 85   В начале марта 2022 года SAP остановила бизнес...
# 87   Такие компании, как Riot Games, GitHub, OpenAI...
# 88   Как сообщается, облачные сервисы Microsoft буд...
# 91   Со своей стороны мы сделаем все, чтобы переход...
# 92   Silicon Angle сообщает, что это крупнейшее пог...
# 96   В апреле Яндекс представил нейросеть Шедеврум ...
# 97   Кроме того, специалисты Softline нарастят эксп...
# 99   По расчётам Cisco, это положительно скажется н...
# 107  Positive Technologies компания является разраб...
# 109  Внеочередное общее собрание акционеров Positiv...
# 110  Кроме того, Nubes обеспечил максимально высоки...
#
#                       object  tonality  \
# 0    Digital Risk Protection  positive
# 4                  Microsoft   neutral
# 5                      Солар  positive
# 6                 Proofpoint  positive
# 10           FortiGuard Labs  positive
# 14       GuidePoint Security  positive
# 21                  Вкусвилл  positive
# 24                  Softline  positive
# 25          Скай Технолоджис  positive
# 26                      ESET  positive
# 32     Positive Technologies  positive
# 34               NGR Softlab  positive
# 35               NGR Softlab  positive
# 43                 Microsoft  positive
# 45                  Group IB  negative
# 48     Positive Technologies  positive
# 51   Лаборатория Касперского  positive
# 52                   Zscaler  positive
# 53                    Dr Web  positive
# 54               Bitdefender  positive
# 56      Astrum Entertainment  positive
# 58                 QIWI Банк  negative
# 66                F.A.C.C.T.  positive
# 70           Angara Security  positive
# 71                    Yandex  negative
# 72                 InfoWatch  negative
# 74                    Amazon  negative
# 75                 Microsoft  negative
# 76                 Microsoft  negative
# 83                    GitLab  negative
# 85                       SAP  negative
# 87                Riot Games  positive
# 88                 Microsoft  negative
# 91               Контур Толк   neutral
# 92             Silicon Angle   neutral
# 96                    Яндекс   neutral
# 97                  Softline   neutral
# 99                     Cisco   neutral
# 107    Positive Technologies   neutral
# 109    Positive Technologies   neutral
# 110                    Nubes   neutral
#
#                                         sentiment-lite
# 0                                              neutral
# 4                                             negative
# 5    в интернете есть много сайтов с информацией на...
# 6    в интернете есть много сайтов с информацией на...
# 10                                             neutral
# 14                                            negative
# 21                                             neutral
# 24                                             neutral
# 25                                             neutral
# 26                                             neutral
# 32                                             neutral
# 34                                             neutral
# 35                                             neutral
# 43                                             neutral
# 45   в интернете есть много сайтов с информацией на...
# 48                                            negative
# 51                                             neutral
# 52                                            negative
# 53                                            negative
# 54                                             neutral
# 56                                             neutral
# 58   в интернете есть много сайтов с информацией на...
# 66   в интернете есть много сайтов с информацией на...
# 70                                             neutral
# 71   в интернете есть много сайтов с информацией на...
# 72   в интернете есть много сайтов с информацией на...
# 74   в интернете есть много сайтов с информацией на...
# 75   в интернете есть много сайтов с информацией на...
# 76   в интернете есть много сайтов с информацией на...
# 83   в интернете есть много сайтов с информацией на...
# 85   в интернете есть много сайтов с информацией на...
# 87                                             neutral
# 88   в интернете есть много сайтов с информацией на...
# 91                                            positive
# 92                                            positive
# 96                                            positive
# 97                                            positive
# 99                                            positive
# 107                                           positive
# 109                                           positive
# 110                                           positive

# %% [markdown]
#   Анализ ошибок модели показывает что, модель часто выдает предсказание neutral в место positive и наоборот. Также на часть запросов модель предлагает поиск в интернете, большенство и зтаких запросов имеют лабел negative и вероятно такой ответ связан с цензурой. В других эксперементах модель отказывалась давать ответ выдавая сообщение указывающее на цензуру.
#   Так же проведенные эксперементы показали что нет существенной разницы в ответах lite и pro моделей

# %%
def base_classifier(sentence: str, company: str, retries: int = 5, delay: int = 1) -> str:
    """
    Функция для классификации тональности упоминания компании на базе YandexGPT.

    Параметры:
    sentence (str): Текст, который нужно проанализировать.
    company (str): Название компании, для которой анализируется тональность упоминания.
    retries (int, optional): Количество попыток при возникновении ошибок или превышении лимита запросов. По умолчанию 5.
    delay (int, optional): Время задержки перед повторной попыткой (в секундах). По умолчанию 1.

    Возвращает:
    str: Наиболее вероятная тональность из возможных ("positive", "negative", "neutral").
         Возвращает None, если не удается получить результат.
    """
    URL = "https://llm.api.cloud.yandex.net/foundationModels/v1/fewShotTextClassification"

    # Задержка перед началом выполнения (если требуется)
    time.sleep(delay)

    # Получаем API-ключ и ID папки из переменных окружения
    api_key = os.getenv("API_KEY")
    folder_id = os.getenv("FOLDER_ID")

    # Собираем запрос с параметрами для классификации
    data = {
        "modelUri": f"cls://{folder_id}/yandexgpt/latest",
        "taskDescription": f"Оцени тональность упоминания компании {company}.",
        "labels": ["positive", "negative", "neutral"],
        "text": sentence
    }

    # Попытка выполнить запрос до указанного числа retries
    for attempt in range(retries):
        try:
            # Отправляем POST-запрос на сервер YandexGPT
            response = requests.post(
                URL,
                headers={
                    "Accept": "application/json",
                    "Authorization": f"Api-Key {api_key}"
                },
                json=data,
            ).json()  # Ожидаем, что ответ придёт в формате JSON

            # Проверяем наличие поля 'predictions' в ответе
            if 'predictions' in response:
                # Выбираем метку с наибольшей уверенностью
                best_prediction = max(response['predictions'], key=lambda x: x['confidence'])
                best_label = best_prediction['label']
                return best_label

            # Если 'predictions' не найдено, выводим сообщение об ошибке
            print(f"Не найдено поле 'predictions' в ответе: {response}")
            return None

        except Exception as e:
            # Если возникает ошибка лимита запросов (например, код 8), повторяем попытку
            if isinstance(response, dict) and response.get('code') == 8:
                print(f"Превышен лимит запросов: попытка {attempt + 1} из {retries}. Ожидание {delay} секунд.")
                time.sleep(delay)  # Задержка перед новой попыткой
            else:
                # Если возникает другая ошибка, выводим её и завершаем выполнение
                print(f"Произошла ошибка: {e}")
                return None

    # Если все попытки исчерпаны, выводим сообщение
    print("Превышено количество попыток.")
    return None

# Пример использования
sentence = "Лидеры ВОГ не избавлялись от непрофильных активов в Вологде, Казани, Липецке, Новосибирске, Омске и Калининградской области, а продавали их по заниженной цене, отметили правоохранители."
company = "ВОГ"
base_classifier(sentence, company)
# Out:
# 'negative'

# %%
# Добавляем в таблицу столбец с результатами слассификатора
data['sentiment-classifieer-label'] = data.apply(lambda row: base_classifier(row['sentence'], row['object']),
    axis=1,
 )

# %%
# Оценка точность модели классификатора
accuracy =len(data[data['sentiment-classifieer-label'] == data['tonality']])/len(data)
print(f"Точность классификатора: {accuracy}")
# Out:
# Точность классификатора: 0.6216216216216216

# %%
# Позиции с ошибочными оценками классификатора
data[data['sentiment-classifieer-label'] != data['tonality']]
# Out:
#                                               sentence  \
# 0    Схему обнаружили аналитики департамента Digita...
# 2    Полиция задержала президента общества глухих С...
# 4    В январе в Microsoft заявили, что киберпреступ...
# 5    Атака NGC2180 была обнаружена специалистами Со...
# 6    ИБ компания Proofpoint обнаружила, что группир...
# 9    Исследователи FortiGuard Labs выявили автора в...
# 10   Специалисты FortiGuard Labs выявили новый вари...
# 14   ИБ компания GuidePoint Security обнаружила, чт...
# 21   Также в марте Вкусвилл получил 80% в компании ...
# 24   Softline через свою 100% ную дочку Скай Технол...
# 25   Скай Технолоджис , на 100% дочерняя ГК Softlin...
# 26   Словацкая компания ESET обнаружила деятельност...
# 34   Евгений присоединился к NGR Softlab в 2023 г.,...
# 35   Российский разработчик решений по информационн...
# 38   Данную схему нашли работники компании F.A.C.C....
# 47   Группа компаний Astra получила 80% российского...
# 48   Ранее, в 2021 г., специалисты Positive Technol...
# 52   В 2022 году исследователи из компании Zscaler,...
# 53   Исследователи Dr Web обнаружили множество прил...
# 54   Напомним, что недавно специалисты Bitdefender ...
# 56   Игровой издатель и разработчик Astrum Entertai...
# 66   На фоне недавних президентских выборов в РФ, и...
# 70   К Angara Security на позиции директора по упра...
# 72   Также под ограничения со стороны Киева попали ...
# 74   С 20 марта в России перестанут работать облачн...
# 75   Обращаем внимание, что речь может идти о всех ...
# 80   Сегодня в ТОП 5 - вредоносные пакеты в Python ...
# 82   Эксперты Cloudflare раскрыли детали атаки на с...
# 87   Такие компании, как Riot Games, GitHub, OpenAI...
# 91   Со своей стороны мы сделаем все, чтобы переход...
# 92   Silicon Angle сообщает, что это крупнейшее пог...
# 96   В апреле Яндекс представил нейросеть Шедеврум ...
# 97   Кроме того, специалисты Softline нарастят эксп...
# 99   По расчётам Cisco, это положительно скажется н...
# 100  Это поможет выявить киберугрозы до того, как з...
# 101  А поскольку наше облако сертифицировано по ФЗ ...
# 104  Продукт для выявления киберугроз на конечных т...
# 105  Confident и Rubintech провели испытания и подт...
# 107  Positive Technologies компания является разраб...
# 108  Компания DarwinAI разработала технологию искус...
# 109  Внеочередное общее собрание акционеров Positiv...
# 110  Кроме того, Nubes обеспечил максимально высоки...
#
#                       object  tonality  \
# 0    Digital Risk Protection  positive
# 2                        ВОГ  negative
# 4                  Microsoft   neutral
# 5                      Солар  positive
# 6                 Proofpoint  positive
# 9            FortiGuard Labs  positive
# 10           FortiGuard Labs  positive
# 14       GuidePoint Security  positive
# 21                  Вкусвилл  positive
# 24                  Softline  positive
# 25          Скай Технолоджис  positive
# 26                      ESET  positive
# 34               NGR Softlab  positive
# 35               NGR Softlab  positive
# 38                F.A.C.C.T.  positive
# 47                     Astra  positive
# 48     Positive Technologies  positive
# 52                   Zscaler  positive
# 53                    Dr Web  positive
# 54               Bitdefender  positive
# 56      Astrum Entertainment  positive
# 66                F.A.C.C.T.  positive
# 70           Angara Security  positive
# 72                 InfoWatch  negative
# 74                    Amazon  negative
# 75                 Microsoft  negative
# 80           Минцифры России  negative
# 82                Cloudflare  negative
# 87                Riot Games  positive
# 91               Контур Толк   neutral
# 92             Silicon Angle   neutral
# 96                    Яндекс   neutral
# 97                  Softline   neutral
# 99                     Cisco   neutral
# 100    Positive Technologies   neutral
# 101            Timeweb Cloud   neutral
# 104    Positive Technologies   neutral
# 105                Confident   neutral
# 107    Positive Technologies   neutral
# 108                 DarwinAI   neutral
# 109    Positive Technologies   neutral
# 110                    Nubes   neutral
#
#                                         sentiment-lite  \
# 0                                              neutral
# 2                                             negative
# 4                                             negative
# 5    в интернете есть много сайтов с информацией на...
# 6    в интернете есть много сайтов с информацией на...
# 9                                             positive
# 10                                             neutral
# 14                                            negative
# 21                                             neutral
# 24                                             neutral
# 25                                             neutral
# 26                                             neutral
# 34                                             neutral
# 35                                             neutral
# 38                                            positive
# 47                                            positive
# 48                                            negative
# 52                                            negative
# 53                                            negative
# 54                                             neutral
# 56                                             neutral
# 66   в интернете есть много сайтов с информацией на...
# 70                                             neutral
# 72   в интернете есть много сайтов с информацией на...
# 74   в интернете есть много сайтов с информацией на...
# 75   в интернете есть много сайтов с информацией на...
# 80                                            negative
# 82                                            negative
# 87                                             neutral
# 91                                            positive
# 92                                            positive
# 96                                            positive
# 97                                            positive
# 99                                            positive
# 100                                            neutral
# 101                                            neutral
# 104                                            neutral
# 105                                            neutral
# 107                                           positive
# 108                                            neutral
# 109                                           positive
# 110                                           positive
#
#     sentiment-classifieer-label
# 0                       neutral
# 2                       neutral
# 4                      negative
# 5                       neutral
# 6                       neutral
# 9                      negative
# 10                     negative
# 14                     negative
# 21                      neutral
# 24                      neutral
# 25                      neutral
# 26                     negative
# 34                      neutral
# 35                      neutral
# 38                      neutral
# 47                      neutral
# 48                     negative
# 52                     negative
# 53                     negative
# 54                     negative
# 56                      neutral
# 66                     negative
# 70                      neutral
# 72                      neutral
# 74                      neutral
# 75                      neutral
# 80                      neutral
# 82                     positive
# 87                      neutral
# 91                     positive
# 92                     positive
# 96                     positive
# 97                     positive
# 99                     positive
# 100                    positive
# 101                    positive
# 104                    positive
# 105                    positive
# 107                    positive
# 108                    positive
# 109                    positive
# 110                    positive

# %% [markdown]
# Несмотря на то что accurecy моделей примерно равны, так как у классификатора нет цензуры и он дал ответы на все запросы, а liti модель часть часть запросов проигнорировала. Можно сделать вывод что на тех запросах где lite модель дает ответ ее качество выше чем у классификатора.

# %%
#  Для позиций где небыл получен ответ от  lite модели примениним классификатор
valid_sentiments = ['negative', 'neutral', 'positive']

# Применяем условие и замену через apply()
data['sentiment-lite'] = data.apply(
    lambda row: row['sentiment-lite']
                if row['sentiment-lite'] in valid_sentiments
                else base_classifier(row['sentence'], row['object']),
    axis=1
)

# %%
# Оценка accuracy полученных результатов
accuracy =len(data[data['sentiment-lite'] == data['tonality']])/len(data)
print(f"Точность lite модели с класификацей цензурированных запросов: {accuracy}")
# Out:
# Точность lite модели с класификацей цензурированных запросов: 0.6936936936936937

# %% [markdown]
# ## Применение более формализованного промта

# %% [markdown]
# Для повышения качества анализа используем более сложный промт с формализацие классов

# %%
#  Инициализация фунции с более сложным промтом
def sentiment(sentence: str, company: str,   retries: int = 5, delay: int = 1, model: str = 'lite') -> str | None:
    """
    Классифицирует тональность предложения с упоминанием компании, возвращая одно из значений: 'negative', 'neutral' или 'positive'.

    Параметры:
    - sentence (str): Предложение, в котором необходимо оценить тональность.
    - company (str): Название компании, упоминание которой оценивается.
    - retries (int, по умолчанию 5): Количество попыток при неудачном запросе.
    - delay (int, по умолчанию 1): Время задержки между повторными попытками в секундах.
    - model (str, по умолчанию 'lite'): Тип модели для использования — 'lite' для упрощённой версии или 'pro' для полной версии.

    Возвращаемое значение:
    - str: Одно из значений 'negative', 'neutral' или 'positive', если запрос выполнен успешно.
    - None: Если произошла ошибка или количество попыток исчерпано.
    """

    # URL для обращения к модели Yandex GPT
    URL = "https://llm.api.cloud.yandex.net/foundationModels/v1/completion"
    # Получаем API ключ и ID папки из переменных окружения
    api_key = os.getenv("API_KEY")
    folder_id = os.getenv("FOLDER_ID")

    # Инициализируем пустой словарь для данных запроса
    data = {}

    # Выбор модели в зависимости от переданного параметра
    if model == 'lite':
        data["modelUri"] = f"gpt://{folder_id}/yandexgpt-lite/latest"  # lite-версия модели
    elif model == 'pro':
        data["modelUri"] = f"gpt://{folder_id}/yandexgpt/latest"  # pro-версия модели
    else:
        print("Неправильная модель, доступные модели 'lite' и 'pro'")
        return None  # Завершаем выполнение функции, если модель указана неверно

    # Настройка опций генерации
    data["completionOptions"] = {"temperature": 0.3, "maxTokens": 500}  # Температура и максимальное количество токенов

    # Простой системный промт для модели с инструкцией по оценке тональности
    system_prompt = f"""Оцени тональность упоминания компании {company}, ответь одним словом negative, neutral или positive.

    Используй следующие критерии для определения тональности:

    POSITIVE тональность:
    - Рост финансовых показателей (выручка, прибыль)
    - Успешные сделки, поглощения, IPO
    - Расширение бизнеса, выход на новые рынки
    - Технологические достижения, инновации
    - Для ИБ-компаний: обнаружение угроз/уязвимостей
    - Получение патентов, сертификатов
    - Рост команды, открытие офисов
    - Позитивные назначения руководителей

    NEGATIVE тональность:
    - Падение финансовых показателей
    - Убытки, банкротство
    - Отзыв лицензий
    - Взломы систем компании
    - Утечки данных клиентов
    - Уязвимости в продуктах (кроме ИБ-компаний)
    - Судебные иски против компании
    - Обвинения в нарушениях
    - Санкции, уход с рынка

    NEUTRAL тональность:
    - Описание продуктов без оценки
    - Цитаты представителей компании
    - Упоминания в списках
    - Технические характеристики
    - Процессы внедрения
    - Планы и стратегии
    - Прогнозы без конкретных результатов
    Запомни: в ответе должно быть только одно слово - negative, neutral или positive, без пояснений и дополнительного текста."""

    # Формируем сообщения для передачи в модель (системный и пользовательский контекст)
    data["messages"] = [
        {"role": "system", "text": system_prompt},  # Системная инструкция
        {"role": "user", "text": sentence}  # Текст, который пользователь хочет классифицировать
    ]

    # Цикл для повторных попыток запроса в случае ошибки или превышения лимитов
    for attempt in range(retries):
        try:
            # Отправляем POST-запрос к API Yandex GPT с данными и заголовками
            response = requests.post(
                URL,
                headers={
                    "Accept": "application/json",
                    "Authorization": f"Api-Key {api_key}"  # Авторизация с использованием API ключа
                },
                json=data,  # Передаем данные запроса
            ).json()

            # Возвращаем результат — одно слово с оценкой тональности, переведенное в нижний регистр
            return response["result"]["alternatives"][0]['message']['text'].lower().rstrip(".")

        except Exception as e:
            # Проверяем, если произошла ошибка лимита запросов (HTTP 429)
            if response.get('error', {}).get('httpCode') == 429:
                print(f"Превышен лимит запросов. Попытка {attempt + 1} из {retries}. Ожидание {delay} секунд.")
                time.sleep(delay)  # Ждем перед новой попыткой
            else:
                # Любая другая ошибка выводится в консоль
                print(f"Произошла ошибка: {e}")
                return None  # Возвращаем None при ошибке

    # Если все попытки исчерпаны, выводим сообщение
    print("Превышено количество попыток.")
    return None  # Возвращаем None, если все попытки завершились неудачно


def classifier(sentence, company, retries=5, delay=1):
    URL = "https://llm.api.cloud.yandex.net/foundationModels/v1/fewShotTextClassification"
    time.sleep(delay)
    api_key = os.getenv("API_KEY")
    folder_id = os.getenv("FOLDER_ID")

    # Собираем запрос
    data = {}
    data["modelUri"] = f"cls://{folder_id}/yandexgpt/latest"
    data["taskDescription"] = f"""Оцени тональность упоминания компании {company}.

    Используй следующие критерии для определения тональности:

    POSITIVE тональность:
    - Рост финансовых показателей (выручка, прибыль)
    - Успешные сделки, поглощения, IPO
    - Расширение бизнеса, выход на новые рынки
    - Технологические достижения, инновации
    - Для ИБ-компаний: обнаружение угроз/уязвимостей
    - Получение патентов, сертификатов
    - Рост команды, открытие офисов
    - Позитивные назначения руководителей

    NEGATIVE тональность:
    - Падение финансовых показателей
    - Убытки, банкротство
    - Отзыв лицензий
    - Взломы систем компании
    - Утечки данных клиентов
    - Уязвимости в продуктах (кроме ИБ-компаний)
    - Судебные иски против компании
    - Обвинения в нарушениях
    - Санкции, уход с рынка

    NEUTRAL тональность:
    - Описание продуктов без оценки
    - Цитаты представителей компании
    - Упоминания в списках
    - Технические характеристики
    - Процессы внедрения
    - Планы и стратегии
    - Прогнозы без конкретных результатов"""

    data["labels"] = ["positive", "negative", "neutral"]
    data["text"] = sentence
    for attempt in range(retries):
        try:
            # Отправляем запрос
            response = requests.post(
                URL,
                headers={
                    "Accept": "application/json",
                    "Authorization": f"Api-Key {api_key}"
                },
                json=data,
            ).json()  # Ожидаем, что ответ будет JSON

            # Проверяем, что в ответе есть 'predictions'
            if 'predictions' in response:
                best_prediction = max(response['predictions'], key=lambda x: x['confidence'])
                best_label = best_prediction['label']
                return best_label

            # Если нет поля predictions, выводим ошибку
            print(f"Не найдено поле 'predictions' в ответе: {response}")
            return None

        except Exception as e:
            # Проверяем на лимит запросов
            if isinstance(response, dict) and response.get('code') == 8:
                print(f"Превышен лимит запросов: попытка {attempt + 1} из {retries}. Ожидание {delay} секунд.")
                time.sleep(delay)  # Задержка перед повторной попыткой
            else:
                print(f"Произошла ошибка: {e}")
                return None
    print("Превышено количество попыток.")
    return None

# %%
# Добавим в dataframe столбец с результатами функции sentiment()
data['sentiment'] = data.apply(lambda row: sentiment(row['sentence'], row['object'],   model='lite'), axis=1)

#  Для позиций где небыл получен ответ от  lite модели примениним классификатор
valid_sentiments = ['negative', 'neutral', 'positive']

data['sentiment'] = data.apply(
    lambda row: row['sentiment']
                if row['sentiment'] in valid_sentiments
                else classifier(row['sentence'], row['object']),
    axis=1
)
# Out:
# Превышен лимит запросов. Попытка 1 из 5. Ожидание 1 секунд.

# %%
# Оценка accuracy полученных результатов
accuracy =len(data[data['sentiment'] == data['tonality']])/len(data)
print(f"Точность с применением более точного промта: {accuracy}")
# Out:
# Точность с применением более точного промта: 0.8018018018018018

# %%
# Позиции с ошибочными оценками
data[data['sentiment'] != data['tonality']][['sentence','object','tonality','sentiment']]
# Out:
#                                               sentence                 object  \
# 4    В январе в Microsoft заявили, что киберпреступ...              Microsoft
# 14   ИБ компания GuidePoint Security обнаружила, чт...    GuidePoint Security
# 26   Словацкая компания ESET обнаружила деятельност...                   ESET
# 34   Евгений присоединился к NGR Softlab в 2023 г.,...            NGR Softlab
# 48   Ранее, в 2021 г., специалисты Positive Technol...  Positive Technologies
# 52   В 2022 году исследователи из компании Zscaler,...                Zscaler
# 53   Исследователи Dr Web обнаружили множество прил...                 Dr Web
# 56   Игровой издатель и разработчик Astrum Entertai...   Astrum Entertainment
# 66   На фоне недавних президентских выборов в РФ, и...             F.A.C.C.T.
# 70   К Angara Security на позиции директора по упра...        Angara Security
# 72   Также под ограничения со стороны Киева попали ...              InfoWatch
# 75   Обращаем внимание, что речь может идти о всех ...              Microsoft
# 87   Такие компании, как Riot Games, GitHub, OpenAI...             Riot Games
# 92   Silicon Angle сообщает, что это крупнейшее пог...          Silicon Angle
# 96   В апреле Яндекс представил нейросеть Шедеврум ...                 Яндекс
# 97   Кроме того, специалисты Softline нарастят эксп...               Softline
# 98   F.A.C.C.T., как передают Ведомости , также отм...             F.A.C.C.T.
# 99   По расчётам Cisco, это положительно скажется н...                  Cisco
# 100  Это поможет выявить киберугрозы до того, как з...  Positive Technologies
# 107  Positive Technologies компания является разраб...  Positive Technologies
# 109  Внеочередное общее собрание акционеров Positiv...  Positive Technologies
# 110  Кроме того, Nubes обеспечил максимально высоки...                  Nubes
#
#      tonality sentiment
# 4     neutral  negative
# 14   positive  negative
# 26   positive  negative
# 34   positive   neutral
# 48   positive  negative
# 52   positive  negative
# 53   positive  negative
# 56   positive   neutral
# 66   positive  negative
# 70   positive   neutral
# 72   negative   neutral
# 75   negative   neutral
# 87   positive   neutral
# 92    neutral  positive
# 96    neutral  positive
# 97    neutral  positive
# 98    neutral  negative
# 99    neutral  positive
# 100   neutral  positive
# 107   neutral  positive
# 109   neutral  positive
# 110   neutral  positive
